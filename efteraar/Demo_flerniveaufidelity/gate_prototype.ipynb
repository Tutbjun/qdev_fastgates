# %%
#determine wether it is run by user or external script
CONFIG_FILENAME = 'gate_prototype_inputs.config'
with open(CONFIG_FILENAME,"r") as f:
    tg_by_tau = f.readline().split(" = ")[1].strip()
user = False

if user == False:
    doPlt = False
else:
    doPlt = True

import numpy as np
import qutip as qt
#omega_d = 243e-3*2*np.pi
#omega_01 = 243e-3*2*np.pi
#load diagonalized Hamiltonian, n opperator and phi opperator
H = np.load('HDiag_fluxonium.npy')
n = np.load('coupling_n_fluxonium.npy')
phi = np.load('coupling_phi_fluxonium.npy')

omega_01 = H[1,1]-H[0,0]
omega_d = omega_01

dim = len(H)

#make idealized and effective pauli opperators
sigma_x, sigma_y, sigma_z = np.zeros((dim,dim),dtype=complex), np.zeros((dim,dim),dtype=complex), np.zeros((dim,dim),dtype=complex)
ident = np.zeros((dim,dim),dtype=complex)
ident[:2,:2] += np.eye(2)
sigma_x[:2,:2] += qt.sigmax().full()
sigma_y[:2,:2] += qt.sigmay().full()
sigma_z[:2,:2] += qt.sigmaz().full()
sigma_x, sigma_y, sigma_z = qt.Qobj(sigma_x), qt.Qobj(sigma_y), qt.Qobj(sigma_z)
ident = qt.Qobj(ident)
sigma_x_eff = qt.Qobj(n)
sigma_y_eff = qt.Qobj(phi)
#sigma_z_eff = qt.Qobj(H)
#normalize x and y opperators by expectation value in |<0|n|1>|^2
exp_n = np.abs(n[0,1])**2
exp_phi = np.abs(phi[0,1])**2
sigma_x_eff = sigma_x_eff/np.sqrt(exp_n)
sigma_y_eff = sigma_y_eff/np.sqrt(exp_phi)


tau = 2*np.pi/omega_d
#t_g = 5*tau

if not user:
    
    tg_by_tau = float(tg_by_tau)
    t_g = tg_by_tau*tau
else:
    t_g = 0.5*tau

# %%
import qutip as qt
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
qt.about()
# Out:
# QuTiP: Quantum Toolbox in Python
# ================================
# Copyright (c) QuTiP team 2011 and later.
# Current admin team: Alexander Pitchford, Nathan Shammah, Shahnawaz Ahmed, Neill Lambert, Eric Giguère, Boxi Li, Jake Lishman, Simon Cross, Asier Galicia, Paul Menczel, and Patrick Hopf.
# Board members: Daniel Burgarth, Robert Johansson, Anton F. Kockum, Franco Nori and Will Zeng.
# Original developers: R. J. Johansson & P. D. Nation.
# Previous lead developers: Chris Granade & A. Grimsmo.
# Currently developed through wide collaboration. See https://github.com/qutip for details.
#
# QuTiP Version:      5.0.4
# Numpy Version:      2.1.1
# Scipy Version:      1.14.1
# Cython Version:     None
# Matplotlib Version: 3.9.2
# Python Version:     3.12.2
# Number of CPUs:     16
# BLAS Info:          Generic
# INTEL MKL Ext:      False
# Platform Info:      Linux (x86_64)
# Installation path:  /home/ubuntu-compute/miniconda3/envs/qdev/lib/python3.12/site-packages/qutip
# ================================================================================
# Please cite QuTiP in your publication.
# ================================================================================
# For your convenience a bibtex reference can be easily generated using `qutip.cite()`

# %%
state1_pops = {}

#tlist = np.linspace(0, 5*t_g, 50)
#sz, sx, sy = sigma_z, sigma_x, sigma_y
#fund_11 = (qt.qeye(2) - sz)/2
#fund_01 = (sigma_x+1j*sigma_y)/2
#fund_10 = (sigma_x-1j*sigma_y)/2
fund_11,fund_01,fund_10 = np.zeros((dim,dim),dtype=complex), np.zeros((dim,dim),dtype=complex), np.zeros((dim,dim),dtype=complex)
fund_11 += ((ident - sigma_z)/2).full()
fund_01 += ((sigma_x+1j*sigma_y)/2).full()
fund_10 += ((sigma_x-1j*sigma_y)/2).full()
fund_11,fund_01,fund_10 = qt.Qobj(fund_11), qt.Qobj(fund_01), qt.Qobj(fund_10)
announcedDeltat0 = True
loss_log = {}


Delta_t0 = -t_g/4*(1+omega_01/omega_d)
while Delta_t0 < 0: Delta_t0 += 2*np.pi/omega_d
tlist = np.linspace(Delta_t0-t_g*0.1, Delta_t0 + 1.1*t_g, 2000)
if tlist[0] < 0:
    tlist += 2*np.pi/omega_d
    Delta_t0 += 2*np.pi/omega_d
envelope_func = lambda t, Omega, Delta_t0, t_g: Omega*np.sin(np.pi*(t-Delta_t0)/t_g)**2 if (t > Delta_t0 and t < Delta_t0 + t_g) else 0
phase_log = {}
hbar = 1
Delta_varphi = 0# x gate
varphi = 0
t_0 = 0
def H_func(t):
    #phase_log[t] = -1j*hbar/4 * (1 + 1j*np.exp(-1j*Delta_varphi)+ np.exp(-2j*omega_d*t)*(1 + 1j*np.exp(1j*Delta_varphi)))
    #var = -1j*hbar/4 * (1 + 1j*np.exp(-1j*Delta_varphi)+ np.exp(-2j*omega_d*t)*(1 + 1j*np.exp(1j*Delta_varphi)))
    var = hbar*np.exp(1j*varphi)/2*(1+np.exp(-1j*((omega_01+omega_d)*(t-t_0) + 2*omega_d*t_0+2*varphi)))
    phase_log['H'][t] = var
    return var
glob_Omega = 1
glob_Delta_t0 = 0
def together_func(t):
    global glob_Omega
    var = H_func(t)*envelope_func(t, glob_Omega, glob_Delta_t0, t_g)
    phase_log['envelope'][t] = var
    return var

maxOmega = 1
def do_sim(Omega,t_g, Delta_t0,optimizeReturn=None, prepState=None):
    global tlist
    global fund_11
    global fund_01
    global fund_10
    global announcedDeltat0
    global loss_log
    global envelope_func
    global omega_01
    global omega_d
    global phase_log
    global glob_Omega
    global glob_Delta_t0
    global maxOmega
    glob_Omega = Omega
    glob_Delta_t0 = Delta_t0
    phase_log = {'H': {}, 'envelope': {}}
    
    if Omega > maxOmega*1.2: return 1e10*Omega
    if Omega < 0: return 1e10*(-Omega+1)
    #units
    #hbar = 1
    #[timeunit] = 1e-9 s
    #[frequnit] = 1e9 Hz
    #[energyunit] = 1e9 hbar Hz
    if prepState is None:
        psi0 = qt.basis(dim, 0)
    else:
        psi0 = prepState
    
    
    #Omega = np.sqrt(2)#*2*np.pi*0.1
    if omega_01 - omega_d == 0:
        H0 = qt.Qobj(0)
    else:
        H0 = qt.QobjEvo([fund_11,(omega_01-omega_d)])*hbar
    
    #H_func = lambda t: -1j*hbar/4 * (1 + 1j*np.exp(-1j*Delta_varphi)+ np.exp(-2j*omega_d*t)*(1 + 1j*np.exp(1j*Delta_varphi)))
    
    #Delta_t0 = 0
    if not announcedDeltat0: print(f"Setting Delta_t0 to {Delta_t0} as compared to t_g of {t_g}")
    
    if not announcedDeltat0: print("Changed Delta_t0 to", Delta_t0)
    
    
    if not announcedDeltat0:
        plt.clf()
        Y = np.zeros_like(tlist)
        for i,t in enumerate(tlist):
            Y[i] = envelope_func(t, Omega, Delta_t0, t_g)
        plt.plot(tlist,Y)
    
    if not announcedDeltat0:
        Y = np.zeros_like(tlist, dtype=complex)
        for i,t in enumerate(tlist):
            Y[i] = together_func(t)
        plt.plot(tlist, Y.real)
        plt.plot(tlist, Y.imag)
        plt.show()
    announcedDeltat0 = True
    #H1 = qt.QobjEvo([fund_01, together_func])
    H1 = qt.QobjEvo([
        (sigma_x_eff + 1j*sigma_y_eff)/2,
        together_func])
    H_ = H1.dag()
    H1 = H1 + H_
    if omega_01 - omega_d == 0:
        H = H1
    else:
        H = H0 + H1
    #H = qt.QobjEvo([H0, H1])#), args={omega_d: omega_d, Omega: Omega, Delta_varphi: Delta_varphi})
    tlist_local = tlist[tlist > Delta_t0 - 0.1*t_g]
    solver = qt.SESolver(H, options={'nsteps':10000})
    result = solver.run(psi0, tlist_local)
    while len(result.states) < len(tlist):
        result.states.insert(0, result.states[0])
    #b = qt.Bloch()
    #b.add_states(result.states, kind='point', colors=['b']*len(result.states))
    #b.title = "Delta_varphi = " + str(Delta_varphi)
    #b.show()
    #state1_pops[Delta_varphi] = qt.expect(fund_11, result.states)
    #return qt.expect(fund_11, result.states)
    #return result.states
    #return the expectation value of the sigma_x operator
    if optimizeReturn == None: return result.states
    if "z" in optimizeReturn:
        #var = qt.expect(sigma_y, result.states[-1])
        var = qt.expect(sigma_z, result.states[-1])
        if optimizeReturn == "z_abs": return var
        var = np.abs(var)**2 * (1+Omega)
        print(Omega, var)
        for O in Omega:
            loss_log[float(O)] = var
        return var
    elif optimizeReturn == "x":
        var = np.abs(qt.expect(sigma_x, result.states[-1]))**2
        print(Delta_t0, var)
        loss_log[float(Omega)] = var
        return var
    else:
        return result.states

def do_sim_Omega(Omega, args):
    print(Omega)
    t_g, Delta_t0, optimizeMode, modifySampling = args
    if modifySampling: Omega = Omega**2
    return do_sim(Omega, t_g, Delta_t0, optimizeMode)

def do_sim_Deltat0(Delta_t0, args):
    print(Delta_t0)
    Omega, t_g, optimizeMode, modifySampling = args
    return do_sim(Omega, t_g, Delta_t0, optimizeMode)

multithread = True

"""Delta_varphi_space = np.linspace(0, 2*np.pi, 500)
if not multithread:
    for Delta_varphi in Delta_varphi_space:
        state1_pops[Delta_varphi] = do_sim(Delta_varphi)
else:
    from multiprocessing import Pool
    p = Pool(10)
    state1_pops = dict(zip(Delta_varphi_space, p.map(do_sim, Delta_varphi_space))
    )
    p.close()
    p.join()"""
from scipy.optimize import minimize, basinhopping
#optimize Omega such that the state is on the equator
#first do sweep of Omega to find zerocrossing of loss function
losess = []
m = 1.5
if t_g < 1: m = 1.5/t_g
for Omega in np.linspace(0, m, 1000):
    loss = do_sim(np.array([Omega]), t_g, Delta_t0, "z_abs")
    losess.append(loss)
    if len(losess) > 1 and losess[-2] > 0 and losess[-1] < 0:
        break
maxOmega = Omega#*1.2

#optimize, but with a max omega of 10
#res = basinhopping(do_sim_Omega, maxOmega, niter=2, minimizer_kwargs={'args':([t_g,Delta_t0,"z",False])}, T=1000)
res = minimize(do_sim_Omega,Omega, args=([t_g,Delta_t0,"z",False]), bounds=[(0.9*Omega,Omega*1.2)], options={'maxiter': 1000})
Omega = res.x[0]
announcedDeltat0 = False
states = do_sim(Omega, t_g, Delta_t0)
print(Omega)
plt.clf()
plt.plot(loss_log.keys(), loss_log.values(), '.')
plt.show()
# Out:
# /home/ubuntu-compute/miniconda3/envs/qdev/lib/python3.12/site-packages/scipy/integrate/_ode.py:1008: ComplexWarning: Casting complex values to real discards the imaginary part
#   y1, t, istate = self.runner(*args)
# [0.19393939]
# [0.19393939] [0.07049251]
# [0.19393941]
# [-0.81606061]
# [-0.81606059]
# [-0.14272719]
# [-0.14272718]
# [0.08171725]
# [0.08171725] [0.44392528]
# [0.08171727]
# [0.08171727] [0.44392512]
# [0.15653201]
# [0.15653201] [5.75710084e-05]
# [0.15653203]
# [0.15653203] [5.75728053e-05]
# [0.18147214]
# [0.18147214] [0.03439755]
# [0.18147215]
# [0.18147215] [0.03439759]
# [0.18978427]
# [0.18978427] [0.0570427]
# [0.18978428]
# [0.18978428] [0.05704275]
# [0.19255456]
# [0.19255456] [0.06583641]
# [0.19255457]
# [0.19255457] [0.06583646]
# [0.19347785]
# [0.19347785] [0.06892066]
# [0.19347787]
# [0.19347787] [0.06892071]
# [0.19378557]
# [0.19378557] [0.06996639]
# [0.19378558]
# [0.19378558] [0.06996644]
# [0.19388813]
# [0.19388813] [0.07031691]
# [0.19388814]
# [0.19388814] [0.07031696]
# [0.19392231]
# [0.19392231] [0.07043396]
# [0.19392232]
# [0.19392232] [0.07043401]
# [0.1939337]
# [0.1939337] [0.07047299]
# [0.19393371]
# [0.19393371] [0.07047304]
# [0.1939375]
# [0.1939375] [0.07048601]
# [0.19393751]
# [0.19393751] [0.07048606]
# [0.19393876]
# [0.19393876] [0.07049034]
# [0.19393878]
# [0.19393878] [0.07049039]
# [0.19393918]
# [0.19393918] [0.07049179]
# [0.1939392]
# [0.1939392] [0.07049184]
# [0.19393932]
# [0.19393932] [0.07049227]
# [0.19393934]
# [0.19393934] [0.07049232]
# [0.19393937]
# [0.19393937] [0.07049243]
# [0.19393939]
# [0.19393939] [0.07049248]
# [0.19393939]
# [0.19393939] [0.07049248]
# [0.1939394]
# [0.19393939]
# [0.19393939] [0.07049251]
# [0.19393941]
# [0.19393939]
# [0.19393939] [0.07049251]
# [0.19393941]
# [0.19393939]
# [0.19393939] [0.07049251]
# [0.19393941]
# [0.19393939]
# [0.19393939] [0.07049251]
# [0.19393941]
# [0.19393939]
# [0.19393939] [0.07049251]
# [0.19393941]
# [0.19393939]
# [0.19393939] [0.07049251]
# [0.19393941]
# [0.19393939]
# [0.19393939] [0.07049251]
# [0.19393941]
# [0.19393939]
# [0.19393939] [0.07049251]
# [0.19393941]
# [0.19393939]
# [0.19393939] [0.07049251]
# [0.19393941]
# [0.19393939]
# [0.19393939] [0.07049251]
# [0.19393941]
# [0.19393939]
# [0.19393939] [0.07049251]
# [0.19393941]
# [0.19393939]
# [0.19393939] [0.07049251]
# [0.19393941]
# [0.19393939]
# [0.19393939] [0.07049251]
# [0.19393941]
# [-0.81606061]
# [-0.31106054]
# [-0.01949864]
# [0.10082137]
# [0.10082137] [0.25030895]
# [0.15353486]
# [0.15353486] [0.00027373]
# [0.1763909]
# /home/ubuntu-compute/miniconda3/envs/qdev/lib/python3.12/site-packages/scipy/integrate/_ode.py:1008: ComplexWarning: Casting complex values to real discards the imaginary part
#   y1, t, istate = self.runner(*args)
# [0.1763909] [0.02311039]
# [0.186319]
# [0.186319] [0.04695057]
# [0.19063016]
# [0.19063016] [0.0596567]
# [0.19250233]
# [0.19250233] [0.0656643]
# [0.19331534]
# [0.19331534] [0.06837201]
# [0.19366839]
# [0.19366839] [0.06956712]
# [0.19382171]
# [0.19382171] [0.07008979]
# [0.48745154]
# [0.48745156]
# [-0.52254846]
# [-0.52254844]
# [0.34923981]
# [0.34923983]
# [0.25445115]
# [0.25445116]
# [-0.13404866]
# [-0.13404864]
# [0.2279464]
# [0.22794641]
# [0.20544094]
# [0.20544095]
# [0.03569614]
# [0.03569614] [0.88988009]
# [0.03569616]
# /home/ubuntu-compute/miniconda3/envs/qdev/lib/python3.12/site-packages/scipy/integrate/_ode.py:1008: ComplexWarning: Casting complex values to real discards the imaginary part
#   y1, t, istate = self.runner(*args)
# [0.03569616] [0.88987999]
# [0.03569614]
# [0.03569614] [0.88988009]
# [0.03569616]
# [0.03569616] [0.88987998]
# [0.03569614]
# [0.03569614] [0.88988008]
# [0.03569616]
# [0.03569616] [0.88987998]
# [0.03569615]
# [0.03569615] [0.88988004]
# [0.03569616]
# [0.03569616] [0.88987994]
# [0.03569617]
# [0.03569617] [0.88987991]
# [0.03569618]
# [0.03569618] [0.88987981]
# [0.03569625]
# [0.03569625] [0.88987936]
# [0.03569626]
# [0.03569626] [0.88987926]
# [0.03569657]
# [0.03569657] [0.88987717]
# [0.03569658]
# [0.03569658] [0.88987706]
# [0.03569784]
# [0.03569784] [0.8898684]
# [0.03569786]
# [0.03569786] [0.8898683]
# [0.03570294]
# [0.03570294] [0.88983332]
# [0.03570295]
# [0.03570295] [0.88983321]
# [0.03572332]
# [0.03572332] [0.88969294]
# [0.03572333]
# [0.03572333] [0.88969284]
# [0.03580484]
# [0.03580484] [0.88913068]
# [0.03580486]
# [0.03580486] [0.88913058]
# [0.03613095]
# [0.03613095] [0.88686935]
# [0.03613096]
# [0.03613096] [0.88686925]
# [0.03743536]
# [0.03743536] [0.87762954]
# [0.03743537]
# [0.03743537] [0.87762944]
# [0.042653]
# [0.042653] [0.83769155]
# [0.04265302]
# [0.04265302] [0.83769143]
# [0.06352358]
# [0.06352358] [0.64023401]
# [0.0635236]
# [0.0635236] [0.64023385]
# [0.14700591]
# [0.14700591] [0.00507432]
# [0.14700592]
# [0.14700592] [0.00507431]
# [0.17106619]
# [0.17106619] [0.0133912]
# [0.17106621]
# [0.17106621] [0.01339122]
# [0.15561489]
# [0.15561489] [7.28442964e-08]
# [0.1556149]
# [0.1556149] [7.29087483e-08]
# [0.15558456]
# [0.15558456] [7.24969608e-10]
# [0.15558458]
# [0.15558458] [7.31413969e-10]
# [0.1555812]
# [0.1555812] [5.14352626e-15]
# [0.15558121]
# [0.15558121] [2.27449398e-15]
# [-0.06461314]
# [-0.06461313]
# [0.94538686]
# [0.94538687]
# [0.44038686]
# [0.44038687]
# [0.38131574]
# [0.38131576]
# [0.33802722]
# [0.33802724]
# [0.13670704]
# [0.13670704] [0.02646406]
# [0.13670706]
# [0.13670706] [0.02646402]
# [0.13670704]
# [0.13670704] [0.02646406]
# [0.13670706]
# [0.13670706] [0.02646402]
# [0.13670704]
# [0.13670704] [0.02646406]
# [0.13670706]
# [0.13670706] [0.02646401]
# [0.13670704]
# [0.13670704] [0.02646406]
# [0.13670706]
# [0.13670706] [0.02646401]
# [0.13670705]
# [0.13670705] [0.02646404]
# [0.13670706]
# [0.13670706] [0.026464]
# [0.13670706]
# [0.13670706] [0.026464]
# [0.13670708]
# [0.13670708] [0.02646395]
# [0.13670712]
# [0.13670712] [0.02646382]
# [0.13670714]
# [0.13670714] [0.02646377]
# [0.13670737]
# [0.13670737] [0.02646309]
# [0.13670738]
# [0.13670738] [0.02646304]
# [0.13670835]
# [0.13670835] [0.02646017]
# [0.13670836]
# [0.13670836] [0.02646013]
# [0.13671227]
# [0.13671227] [0.02644852]
# [0.13671229]
# [0.13671229] [0.02644847]
# [0.13672796]
# [0.13672796] [0.02640192]
# [0.13672797]
# [0.13672797] [0.02640187]
# [0.13679071]
# [0.13679071] [0.02621596]
# [0.13679073]
# [0.13679073] [0.02621592]
# [0.13704173]
# [0.13704173] [0.02547931]
# [0.13704174]
# [0.13704174] [0.02547926]
# [0.13804578]
# [0.13804578] [0.02264592]
# [0.1380458]
# [0.1380458] [0.02264588]
# [0.142062]
# [0.142062] [0.01309263]
# [0.14206202]
# [0.14206202] [0.0130926]
# [0.15361638]
# [0.15361638] [0.00025218]
# [0.1536164]
# [0.1536164] [0.00025218]
# [0.15530401]
# [0.15530401] [4.94522571e-06]
# [0.15530403]
# [0.15530403] [4.94469335e-06]
# [0.1555742]
# [0.1555742] [3.15124575e-09]
# [0.15557421]
# [0.15557421] [3.13785279e-09]
# [0.15558117]
# [0.15558117] [6.69194384e-14]
# [0.15558119]
# [0.15558119] [1.93983135e-14]
# Setting Delta_t0 to (21.22826880547439+0j) as compared to t_g of (14.152179203649593+0j)
# Changed Delta_t0 to (21.22826880547439+0j)
# /home/ubuntu-compute/miniconda3/envs/qdev/lib/python3.12/site-packages/matplotlib/cbook.py:1762: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /home/ubuntu-compute/miniconda3/envs/qdev/lib/python3.12/site-packages/matplotlib/cbook.py:1398: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# 0.1555811956026012

# %%
#do a complex plot of phase_log
plt.clf()

maxv = 0
def plot_phase(dictphase):
    global maxv
    global doPlt
    if not doPlt: return
    #normalize
    maxAbs = np.max(np.abs(list(dictphase.values())))
    for t in dictphase.keys():
        dictphase[t] /= maxAbs
    real = np.zeros(len(dictphase))
    imag = np.zeros(len(dictphase))
    #sort by angle on plane starting from pi/2
    
    for i,t in enumerate(dictphase.keys()):
        real[i] = dictphase[t].real
        imag[i] = dictphase[t].imag
        if np.abs(real[i]) > maxv: maxv = np.abs(real[i])
        if np.abs(imag[i]) > maxv: maxv = np.abs(imag[i])
    angles = np.arctan2(imag, real)
    sort = np.argsort(angles)
    real = real[sort]
    imag = imag[sort]
    plt.plot(real, imag)
plot_phase(phase_log['H'])
plot_phase(phase_log['envelope'])
plt.xlim([-maxv, maxv])
plt.ylim([-maxv, maxv])
plt.show()

# %%
#now minimize for Delta_t0
if False:
    #res = minimize(do_sim_Deltat0, Delta_t0, args=([Omega, t_g, "x"]), bounds=[(0, 10)])
    res = basinhopping(do_sim_Deltat0, Delta_t0, niter=2, minimizer_kwargs={'args':([Omega, t_g, "x"])}, T=1000)
    Delta_t0 = res.x[0]
    announcedDeltat0 = False
    states = do_sim(Omega, t_g, Delta_t0)
    print(Delta_t0)
    plt.clf()

# %%
#alternate between optimizing Omega and Delta_t0 a few times
if False:
    for i in range(10):
        res = minimize(do_sim_Omega, Omega, args=([t_g,Delta_t0,"z"]), bounds=[(0, 10)], options={'maxiter': 1000})
        Omega = res.x[0]
        res = minimize(do_sim_Deltat0, Delta_t0, args=([Omega, t_g, "x"]), bounds=[(0, 10)], options={'maxiter': 1000})
        Delta_t0 = res.x[0]
    announcedDeltat0 = False
    states = do_sim(Omega, t_g, Delta_t0)
    plt.plot(loss_log.keys(), loss_log.values(), '.')
    plt.show()

# %%
if doPlt:
    #animate the complex number of H_func as a function of time, and show a video of it
    #have it be a trailing line animation
    from matplotlib.animation import FuncAnimation
    from matplotlib import rc
    from IPython.display import display
    fig, ax = plt.subplots()
    #draw axis
    ax.axhline(0, color='black', lw=1)
    ax.axvline(0, color='black', lw=1)
    #have continually updated annotation
    anot = ax.annotate("", xy=(0.7, 0.8), xytext=(0, 0), textcoords="offset points", arrowprops=dict(arrowstyle="->"))
    line1, = ax.plot([], [], lw=2, label="delivered pulse [a.u.]", color='red')
    line2, = ax.plot([], [], lw=2, label="H_func", color='blue', linestyle='dashed')
    ax.legend()
    def init():
        ax.set_xlim(-maxv, maxv)
        ax.set_ylim(-maxv, maxv)
        return line1, line2
    cords1_real = []
    cords1_imag = []
    cords2_real = []
    cords2_imag = []
    maxVar = 0
    def update(frame):
        global maxVar
        print(".", end='')
        t = tlist[::5][frame]
        #print(t)
        var = H_func(t)*envelope_func(t, Omega, Delta_t0, t_g)/Omega
        cords1_real.append(var.real)
        cords1_imag.append(var.imag)
        if np.abs(var.real) > maxVar: maxVar = np.abs(var.real)
        if np.abs(var.imag) > maxVar: maxVar = np.abs(var.imag)
        line1.set_data(cords1_real, cords1_imag)
        var = H_func(t)
        cords2_real.append(var.real)
        cords2_imag.append(var.imag)
        if np.abs(var.real) > maxVar: maxVar = np.abs(var.real)
        if np.abs(var.imag) > maxVar: maxVar = np.abs(var.imag)
        line2.set_data(cords2_real, cords2_imag)
        anot.set_text(f"t = {t:.2f}")
        ax.set_xlim(-maxVar, maxVar)
        return line1,
    ani = FuncAnimation(fig, update, frames=range(100), init_func=init, blit=True)
    rc('animation', html='html5')
    display(ani)
    plt.clf()
# Out:
# ....................................................................................................
# <video width="640" height="480" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
states_2plt = [qt.Qobj(state[:2]) for state in states]
def plot_results(states, overWritedoPlt=False):
    global doPlt
    if not doPlt and not overWritedoPlt: return
    #plot the bloch sphere representation of the states and a line plot for the expectation value of sigma_x
    plt.clf()
    fig = plt.figure(constrained_layout=True, figsize=(10,3))
    ax1 = fig.add_subplot(121)
    
    exp_z = qt.expect(qt.sigmaz(), states)
    mask = exp_z < 1
    mask = mask & (abs(exp_z) > 1e-5)
    t_list_local = tlist[mask]
    ey, ex, ez = qt.expect(qt.sigmay(), states), qt.expect(qt.sigmax(), states), qt.expect(qt.sigmaz(), states)
    ax1.plot(t_list_local, ey[mask], label="Expectation value of sigma_y")
    ax1.plot(t_list_local, ez[mask], label="Expectation value of sigma_z")
    ax1.plot(t_list_local, ex[mask], label="Expectation value of sigma_x")
    ax1.legend()
    ax1.set_ylabel("Expectation value")
    ax1.set_xlabel("Time [ns]")
    
    ax2 = fig.add_subplot(122, projection='3d')
    b = qt.Bloch(fig=fig, axes=ax2)
    ax2.set_box_aspect([1,1,1])
    #truncate dimension
    
    
    b.add_states(states, kind='point', colors=['b']*len(states))
    #b.title = "Final state" 
    b.save(dirc='tmp')
    b.show()

plot_results(states_2plt, overWritedoPlt=True)
# Out:
# /home/ubuntu-compute/miniconda3/envs/qdev/lib/python3.12/site-packages/matplotlib/cbook.py:1762: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /home/ubuntu-compute/miniconda3/envs/qdev/lib/python3.12/site-packages/matplotlib/cbook.py:1398: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
def aces_gate(states, Omega, t_g):
    #print the angle of the final state on the equator
    print(f"Optimizer found an Omega of {Omega:.4f} to be needed for the given t_g of {t_g}ns")
    theta = np.arccos(-qt.expect(qt.sigmay(), states[-1]))
    print(f"State is {theta/np.pi:.3f}pi away from the desired -y state")
    print(f"State has a x expectation value of {qt.expect(qt.sigmax(), states[-1]):.3e}")
    print(f"State has a z expectation value of {qt.expect(qt.sigmaz(), states[-1]):.3e}")
    return theta
theta = aces_gate(states_2plt, Omega, t_g)
# Out:
# Optimizer found an Omega of 0.1556 to be needed for the given t_g of (14.152179203649593+0j)ns
# State is 0.131pi away from the desired -y state
# State has a x expectation value of 2.157e-02
# State has a z expectation value of 6.672e-08

# %%
#do the virtual Z gate, linearly applied through the envelope
Z_theta = lambda phi: np.cos(phi/2)*qt.qeye(2) + 1j*np.sin(phi/2)*qt.sigmaz()
tenv = lambda t: (t-Delta_t0)/t_g if (t > Delta_t0) else 0
transformation_envelope = lambda t: tenv(t) if (t < Delta_t0 + t_g) else 1
Z_theta_t = lambda t: Z_theta(transformation_envelope(t)*theta)
for i, state in enumerate(states_2plt):
    states_2plt[i] = Z_theta(-transformation_envelope(tlist[i])*theta)*state
    pass
"""for i, state in enumerate(states):
    states[i] = Z_theta(theta)*state"""
# Out:
# 'for i, state in enumerate(states):\n    states[i] = Z_theta(theta)*state'

# %%
plot_results(states_2plt)
aces_gate(states_2plt, Omega, t_g)
# Out:
# Optimizer found an Omega of 0.1556 to be needed for the given t_g of (14.152179203649593+0j)ns
# State is 0.188pi away from the desired -y state
# State has a x expectation value of 3.869e-01
# State has a z expectation value of 6.672e-08
# np.float64(0.5903070537074001)

# %%
print("Finally found an Omega of", Omega, "and a Delta_t0 of", Delta_t0)
# Out:
# Finally found an Omega of 0.1555811956026012 and a Delta_t0 of (21.22826880547439+0j)

# %%
#use the found parameters to perform an X gate on various other states and check the fidelity
#log angle between final state and desired state
fidelityMeassures = []
blankState = np.zeros(dim, dtype=complex)

def eval_onstate(start_2d,expect_2d):
    #prepState = qt.basis(dim,0)
    if type(start_2d) == qt.Qobj:
        start_2d = start_2d.full().flatten()
    if type(expect_2d) == qt.Qobj:
        expect_2d = expect_2d.full().flatten()
    """if type(expect_op_2d) == qt.Qobj:
        expect_op_2d = expect_op_2d.full().flatten()"""
    prepState = blankState
    prepState[:2] = start_2d
    prepState = qt.Qobj(prepState)
    states = do_sim(Omega, t_g, Delta_t0, prepState=prepState)
    states_2plt = [qt.Qobj(state[:2]) for state in states]
    plot_results(states_2plt)
    aces_gate(states_2plt, Omega, t_g)
    state = states_2plt[-1].full().flatten()
    #fidelity = qt.fidelity(qt.Qobj(expect_2d), states_2plt[-1])
    #fidelity = np.arccos(-qt.expect(qt.sigmay(), states_2plt[-1]))
    #do dot product instead
    
    #fidelity = np.dot(state, expect_2d)
    #fidelity = np.abs(fidelity)**2
    expect_2d = qt.Qobj(expect_2d)
    x_e, y_e, z_e = qt.expect(qt.sigmax(), expect_2d), qt.expect(qt.sigmay(), expect_2d), qt.expect(qt.sigmaz(), expect_2d)
    x_s, y_s, z_s = qt.expect(qt.sigmax(), states_2plt[-1]), qt.expect(qt.sigmay(), states_2plt[-1]), qt.expect(qt.sigmaz(), states_2plt[-1])
    goodness = np.sqrt((x_e-x_s)**2 + (y_e-y_s)**2 + (z_e-z_s)**2)

    #define "goodness" to be the full distance from the desired state
    """goodness_angle = np.arccos(np.abs(np.dot(state, expect_2d)))
    goodnes_radius = np.abs(np.dot(state, expect_2d))
    goodness = np.sqrt(goodness_angle**2 + (1-goodnes_radius)**2)"""

    #goodness = np.sqrt(np.abs(np.dot(np.matmul(expect_op_2d, state),np.matmul(expect_op_2d, state))))
    """expect_op_2d = qt.Qobj(expect_op_2d)
    state = qt.Qobj(state)
    goodness_angle = np.arccos(np.abs(qt.expect(expect_op_2d, state.unit())))
    goodness_radius = np.abs(qt.expect(expect_op_2d, state.unit()))
    goodness = np.sqrt(goodness_angle**2 + (1-goodness_radius)**2)"""


    fidelityMeassures.append(goodness)
    print(goodness)

#eval_onstate(qt.basis(2,0),-(-1j*qt.basis(2,0)+qt.basis(2,1)).unit())
y_minus_eigen = (1j*qt.basis(2,0)+qt.basis(2,1)).unit()
#eval_onstate(qt.basis(2,0),(qt.basis(2,0)-qt.basis(2,1)).unit())
eval_onstate(qt.basis(2,0),y_minus_eigen)
#eval_onstate(qt.basis(2,0),-qt.sigmay())

"""prepState = qt.basis(dim,1)
states = do_sim(Omega, t_g, Delta_t0, prepState=prepState)
states_2plt = [qt.Qobj(state[:2]) for state in states]
plot_results(states_2plt)
aces_gate(states_2plt, Omega, t_g)
#fidelity = qt.fidelity((qt.basis(2,0)+1j*qt.basis(2,1)).unit(), states[-1])
fidelity = np.arccos(qt.expect(qt.sigmay(), states_2plt[-1]))
fidelityMeassures.append(fidelity)
print(fidelity)"""

y_plus_eigen = (1j*qt.basis(2,0)-qt.basis(2,1)).unit()

eval_onstate(qt.basis(2,1),(-1j*qt.basis(2,0)+qt.basis(2,1)).unit())

"""pS = (qt.basis(2,0)+qt.basis(2,1)).unit().full().flatten()
prepState = blankState
prepState[:2] = pS
prepState = qt.Qobj(prepState)
states = do_sim(Omega, t_g, Delta_t0, prepState=prepState)
states_2plt = [qt.Qobj(state[:2]) for state in states]
plot_results(states_2plt)
aces_gate(states_2plt, Omega, t_g)
#fidelity = qt.fidelity((qt.basis(2,0)+qt.basis(2,1)).unit(), states[-1])
#instead do dot by arccos of the dot product
fidelity = np.arccos(qt.expect(qt.sigmax(), states_2plt[-1]))
fidelityMeassures.append(fidelity)
print(fidelity)"""

eval_onstate(
    (qt.basis(2,0)+qt.basis(2,1)).unit(),
    (qt.basis(2,0)+qt.basis(2,1)).unit()
)

"""pS = (qt.basis(2,0)-qt.basis(2,1)).unit().full().flatten()
prepState = blankState
prepState[:2] = pS
prepState = qt.Qobj(prepState)
states = do_sim(Omega, t_g, Delta_t0, prepState=prepState)
states_2plt = [qt.Qobj(state[:2]) for state in states]
plot_results(states_2plt)
aces_gate(states_2plt, Omega, t_g)
#fidelity = qt.fidelity((qt.basis(2,0)-qt.basis(2,1)).unit(), states[-1])
fidelity = np.arccos(qt.expect(-qt.sigmax(), states_2plt[-1]))
fidelityMeassures.append(fidelity)
print(fidelity)
"""

eval_onstate(
    (qt.basis(2,0)-qt.basis(2,1)).unit(),
    (qt.basis(2,0)-qt.basis(2,1)).unit(),
)

"""pS = (qt.basis(2,0)+1j*qt.basis(2,1)).unit().full().flatten()
prepState = blankState
prepState[:2] = pS
prepState = qt.Qobj(prepState)
states = do_sim(Omega, t_g, Delta_t0, prepState=prepState)
states_2plt = [qt.Qobj(state[:2]) for state in states]
plot_results(states_2plt)
aces_gate(states_2plt, Omega, t_g)
#fidelity = qt.fidelity(qt.basis(2,0), states[-1])
fidelity = np.arccos(qt.expect(qt.sigmaz(), states_2plt[-1]))
fidelityMeassures.append(fidelity)
print(fidelity)"""

eval_onstate(
    (y_plus_eigen).unit(),
    qt.basis(2,0)
)

"""pS = (qt.basis(2,0)-1j*qt.basis(2,1)).unit().full().flatten()
prepState = blankState
prepState[:2] = pS
prepState = qt.Qobj(prepState)
states = do_sim(Omega, t_g, Delta_t0, prepState=prepState)
states_2plt = [qt.Qobj(state[:2]) for state in states]
plot_results(states_2plt)
aces_gate(states_2plt, Omega, t_g)
#fidelity = qt.fidelity(qt.basis(2,1), states[-1])
fidelity = np.arccos(-qt.expect(qt.sigmaz(), states_2plt[-1]))
fidelityMeassures.append(fidelity)
print(fidelity)"""

eval_onstate(
    (y_minus_eigen).unit(),
    qt.basis(2,1)
)
# Out:
# /home/ubuntu-compute/miniconda3/envs/qdev/lib/python3.12/site-packages/scipy/integrate/_ode.py:1008: ComplexWarning: Casting complex values to real discards the imaginary part
#   y1, t, istate = self.runner(*args)
# /home/ubuntu-compute/miniconda3/envs/qdev/lib/python3.12/site-packages/matplotlib/cbook.py:1762: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /home/ubuntu-compute/miniconda3/envs/qdev/lib/python3.12/site-packages/matplotlib/cbook.py:1398: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# Optimizer found an Omega of 0.1556 to be needed for the given t_g of (14.152179203649593+0j)ns
# State is 0.131pi away from the desired -y state
# State has a x expectation value of 2.157e-02
# State has a z expectation value of 6.672e-08
# 0.08653620195139122
# Optimizer found an Omega of 0.1556 to be needed for the given t_g of (14.152179203649593+0j)ns
# State is 0.855pi away from the desired -y state
# State has a x expectation value of -2.648e-03
# State has a z expectation value of 1.770e-02
# 0.10299707491757894
# Optimizer found an Omega of 0.1556 to be needed for the given t_g of (14.152179203649593+0j)ns
# State is 0.501pi away from the desired -y state
# State has a x expectation value of 9.168e-01
# State has a z expectation value of 2.096e-02
# 0.08584046195227604
# Optimizer found an Omega of 0.1556 to be needed for the given t_g of (14.152179203649593+0j)ns
# State is 0.493pi away from the desired -y state
# State has a x expectation value of -8.979e-01
# State has a z expectation value of -3.258e-03
# 0.10423688131778945
# Optimizer found an Omega of 0.1556 to be needed for the given t_g of (14.152179203649593+0j)ns
# State is 0.494pi away from the desired -y state
# State has a x expectation value of -2.437e-03
# State has a z expectation value of 9.162e-01
# 0.0856941740881315
# Optimizer found an Omega of 0.1556 to be needed for the given t_g of (14.152179203649593+0j)ns
# State is 0.500pi away from the desired -y state
# State has a x expectation value of 2.136e-02
# State has a z expectation value of -8.985e-01
# 0.10369219302318024

# %%
print("Fidelity meassures:", fidelityMeassures)
import pickle
import os
#pickle it to do logs on performance
"""if not os.path.exists("fid_logs.pickle"):
    logs = {}
    with open("fid_logs.pickle", "wb") as f:
        pickle.dump(logs, f)
with open("fid_logs.pickle", "rb") as f:
    logs = pickle.load(f)
logs[t_g/tau] = fidelityMeassures
with open("fid_logs.pickle", "wb") as f:
    pickle.dump(logs, f)
print("Saved to logs")"""
#instead, save to a tmp file with PID
path = f"tmp/fid_logs_{os.getpid()}.txt"
#path = os.path.join(os.path.dirname(__file__), path)
with open(path, "w") as f:
    f.write(f"{t_g/tau} {fidelityMeassures}\n")
print("Saved to logs")
# Out:
# Fidelity meassures: [np.float64(0.9163221487068675), np.float64(8.911961311422786e-05), np.float64(0.9169372066193265), np.float64(0.8980156923843153), np.float64(0.9163224896150504), np.float64(8.911803421615871e-05)]
# Saved to logs
